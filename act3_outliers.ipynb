# %%
#Librería
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Leer csv
data=pd.read_csv('VentasTotales_SinNulos.csv')
data.head()
# Out:
#    Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0           0    01/01/2017                    27858.9
# 1           1    01/02/2017                    25994.2
# 2           2    01/03/2017                    27780.0
# 3           3    01/04/2017                    29134.3
# 4           4    01/05/2017                    27969.0
#
#    ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                    27477.3                 27858872.08   27591730.13
# 1                    25223.4                 25994200.17   25749179.40
# 2                    26334.3                 27780006.52   27472228.72
# 3                    27045.9                 29134272.22   28827479.49
# 4                    25631.9                 27969004.68   27569311.41
#
#    canales_on_line  ventas_totales_medio_pago      efectivo  tarjetas_debito  \
# 0       267141.956                27858872.08  1.023010e+07      6864575.384
# ...

# %%
data=data.drop('Unnamed: 0',axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   indice_tiempo                        65 non-null     object
#  1   ventas_precios_corrientes            65 non-null     float64
#  2   ventas_precios_constantes            65 non-null     float64
#  3   ventas_totales_canal_venta           65 non-null     float64
#  4   salon_ventas                         65 non-null     float64
#  5   canales_on_line                      65 non-null     float64
#  6   ventas_totales_medio_pago            65 non-null     float64
#  7   efectivo                             65 non-null     float64
#  8   tarjetas_debito                      65 non-null     float64
#  9   tarjetas_credito                     65 non-null     float64
#  10  otros_medios                         65 non-null     float64
# ...

# %%
#Total de valores nulos en el df
data.isnull().sum()
# Out:
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# electronicos_articulos_hogar           0
# ...

# %%
data2=data.copy()

# %% [markdown]
# Encontrar 10 columnas con outliers: 5 con desvest y 5 con iqr

# %%
#Columna 1 con outliers: ventas_precios_corrientes
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['ventas_precios_corrientes'])
plt.title('Outliers de ventas_precios_corrientes')

plt.show()

# %%
#Columna 2 con outliers: ventas_precios_constantes
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['ventas_precios_constantes'])
plt.title('Outliers de ventas_precios_constantes')

plt.show()

# %%
#Columna 3 con outliers: indumentaria_calzado_textiles_hogar
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['indumentaria_calzado_textiles_hogar'])
plt.title('Outliers de indumentaria_calzado_textiles_hogar')

plt.show()

# %%
#Columna 4 con outliers: salon_ventas
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['salon_ventas'])
plt.title('Outliers de salon_ventas')

plt.show()

# %%
#Columna 5 con outliers: tarjetas_debito
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['tarjetas_debito'])
plt.title('Outliers de tarjetas_debito')

plt.show()

# %%
#Columna 6 con outliers: tarjetas_credito
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['tarjetas_credito'])
plt.title('Outliers de tarjetas_credito')

plt.show()

# %%
#Columna 7 con outliers: subtotal_ventas_alimentos_bebidas
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['subtotal_ventas_alimentos_bebidas'])
plt.title('Outliers de subtotal_ventas_alimentos_bebidas')

plt.show()

# %%
#Columna 8 con outliers: bebidas
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['bebidas'])
plt.title('Outliers de bebidas')

plt.show()

# %%
#Columna 9 con outliers: panaderia
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['panaderia'])
plt.title('Outliers de panaderia')

plt.show()

# %%
#Columna 10 con outliers: alimentos_preparados_rotiseria
fig=plt.figure(figsize=(10,6))
plt.boxplot(data2['alimentos_preparados_rotiseria'])
plt.title('Outliers de alimentos_preparados_rotiseria')

plt.show()

# %% [markdown]
# Sustituir las primeras 5 columnas con método de desviación estándar

# %%
#Columna 1: ventas_precios_corrientes
y1=data2['ventas_precios_corrientes']
ls1=y1.mean()+2.9*y1.std()
li1=y1.mean()-2.9*y1.std()
print("Límite superior 1:",ls1)
print("Límite inferior 1:",li1)
# Out:
# Límite superior 1: 209576.87646864733
# Límite inferior 1: -65096.4795455704

# %%
#Outliers en boxplot=1
#Encontrar outliers
outliers_y1=data2[(y1>ls1)|(y1<li1)]
outliers_y1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                 81140696.22   76413721.76      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42                81140696.22  24935747.29      22143208.63        29569224.4
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 24 columns]

# %%
#df con y1 sin outliers
data_clean_y1=data2[(y1<=ls1)&(y1>=li1)] #Eliminar esa fila
data_clean_y1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 2: ventas_precios_constantes
y2=data2['ventas_precios_constantes']
ls2=y2.mean()+1.7*y2.std()#1.7 porque así encuentra los 3 atípicos del boxplot
li2=y2.mean()-1.7*y2.std()#1.7 porque así encuentra los 3 atípicos del boxplot
print("Límite superior 2:",ls2)
print("Límite inferior 2:",li2)
# Out:
# Límite superior 2: 33973.91472471934
# Límite inferior 2: 18153.47604451143

# %%
#Outliers en boxplot=3
#Encontrar outliers
outliers_y2=data2[(y2>ls2)|(y2<li2)]
outliers_y2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 11    01/12/2017                    40766.3                    34084.5
# 42    01/07/2020                   211140.7                    50791.4
# 60    01/01/2022                   154517.1                    45463.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 11                4.076632e+07  4.032029e+07     4.460368e+05
# 42                8.114070e+07  7.641372e+07     4.726974e+06
# 60                1.545171e+08  1.496976e+08     4.819480e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 11               4.076632e+07  13710305.37      11070098.74       14576008.24
# 42               8.114070e+07  24935747.29      22143208.63       29569224.40
# 60               1.545171e+08  46962602.22      46053650.13       54048333.12
#
#     ...       almacen    panaderia       lacteos        carnes  \
# ...

# %%
#df con y2 sin outliers
data_clean_y2=data2[(y2<=ls2)&(y2>=li2)] #Elimina las 3 filas
data_clean_y2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 59    01/12/2021                   183983.2                    31595.7
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 3: indumentaria_calzado_textiles_hogar
y3=data2['indumentaria_calzado_textiles_hogar']
ls3=y3.mean()+2.1*y3.std()#2.1 porque así encuentra los 3 atípicos del boxplot
li3=y3.mean()-2.1*y3.std()#2.1 porque así encuentra los 3 atípicos del boxplot
print("Límite superior 3:",ls3)
print("Límite inferior 3:",li3)
# Out:
# Límite superior 3: 4142735.2482713736
# Límite inferior 3: -590364.7079144507

# %%
#Outliers en boxplot=3
#Encontrar outliers
outliers_y3=data2[(y3>ls3)|(y3<li3)]
outliers_y3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
# 63                 177148082.8   173003799.1      4144283.743
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 63                177148082.8  53189998.68      50063972.79       65357591.09
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# ...

# %%
#df con y3 sin outliers
data_clean_y3=data2[(y3<=ls3)&(y3>=li3)] #Elimina las 3 filas
data_clean_y3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 4: salon_ventas
y4=data2['salon_ventas']
ls4=y4.mean()+2.3*y4.std()#2.3 porque así encuentra los 3 atípicos del boxplot
li4=y4.mean()-2.3*y4.std()#2.3 porque así encuentra los 3 atípicos del boxplot
print("Límite superior 4:",ls4)
print("Límite inferior 4:",li4)
# Out:
# Límite superior 4: 169193449.6825782
# Límite inferior 4: -17521276.86011666

# %%
#Outliers en boxplot=3
#Encontrar outliers
outliers_y4=data2[(y4>ls4)|(y4<li4)]
outliers_y4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
# 63                 177148082.8   173003799.1      4144283.743
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 63                177148082.8  53189998.68      50063972.79       65357591.09
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# ...

# %%
#df con y4 sin outliers
data_clean_y4=data2[(y4<=ls4)&(y4>=li4)] #Elimina las 3 filas
data_clean_y4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 5: tarjetas_debito
y5=data2['tarjetas_debito']
ls5=y5.mean()+2.7*y5.std()#2.7 porque así encuentra los 3 atípicos del boxplot
li5=y5.mean()-2.7*y5.std()#2.7 porque así encuentra los 3 atípicos del boxplot
print("Límite superior 5:",ls5)
print("Límite inferior 5:",li5)
# Out:
# Límite superior 5: 54351006.01788169
# Límite inferior 5: -14561794.70954324

# %%
#Outliers en boxplot=1
#Encontrar outliers
outliers_y5=data2[(y5>ls5)|(y5<li5)]
outliers_y5
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#df con y5 sin outliers
data_clean_y5=data2[(y5<=ls5)&(y5>=li5)] #Elimina esa fila
data_clean_y5
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %% [markdown]
# Sustituir las últimas 5 columnas con método de rango intercuartílico

# %%
#Columna 6: tarjetas_credito
y6=data2['tarjetas_credito']
p25_6=y6.quantile(0.25)
p75_6=y6.quantile(0.75)
iqr6=p75_6-p25_6

ls_iq_6=p75_6+1.5*iqr6
li_iq_6=p25_6-1.5*iqr6
print("Límite superior 6:",ls_iq_6)
print("Límite inferior 6:",li_iq_6)
# Out:
# Límite superior 6: 63856184.05500001
# Límite inferior 6: -16515482.225

# %%
#Outliers en boxplot=2
#Encontrar outliers
outliers_y6=data2[(y6>ls_iq_6)|(y6<li_iq_6)]
outliers_y6
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 63                 177148082.8   173003799.1      4144283.743
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 63                177148082.8  53189998.68      50063972.79       65357591.09
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 63  ...  49991675.91  6746166.557  19309461.59  22877841.24
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 63          6510665.781                     1719458.547
# ...

# %%
#df con y6 sin outliers
data_clean_y6=data2[(y6<=ls_iq_6)&(y6>=li_iq_6)] #Elimina las 2 filas
data_clean_y6
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 58    01/11/2021                   141702.0                    25026.6
# 59    01/12/2021                   183983.2                    31595.7
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 7: subtotal_ventas_alimentos_bebidas
y7=data2['subtotal_ventas_alimentos_bebidas']
p25_7=y7.quantile(0.25)
p75_7=y7.quantile(0.75)
iqr7=p75_7-p25_7

ls_iq_7=p75_7+1.5*iqr7
li_iq_7=p25_7-1.5*iqr7
print("Límite superior 7:",ls_iq_7)
print("Límite inferior 7:",li_iq_7)
# Out:
# Límite superior 7: 114548006.925
# Límite inferior 7: -11790048.954999998

# %%
#Outliers en boxplot=4
#Encontrar outliers
outliers_y7=data2[(y7>ls_iq_7)|(y7<li_iq_7)]
outliers_y7
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37      6.299968e+07
# 62                168982502.3  51262080.99      47364363.88      2.726200e+07
# ...

# %%
#df con y7 sin outliers
data_clean_y7=data2[(y7<=ls_iq_7)&(y7>=li_iq_7)] #Elimina las 4 filas
data_clean_y7
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 56    01/09/2021                   123002.3                    22962.0
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 8: bebidas
y8=data2['bebidas']
p25_8=y8.quantile(0.25)
p75_8=y8.quantile(0.75)
iqr8=p75_8-p25_8

ls_iq_8=p75_8+1.5*iqr8
li_iq_8=p25_8-1.5*iqr8
print("Límite superior 8:",ls_iq_8)
print("Límite inferior 8:",li_iq_8)
# Out:
# Límite superior 8: 22865338.630999997
# Límite inferior 8: -6791560.384999999

# %%
#Outliers en boxplot=1
#Encontrar outliers
outliers_y8=data2[(y8>ls_iq_8)|(y8<li_iq_8)]
outliers_y8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#df con y8 sin outliers
data_clean_y8=data2[(y8<=ls_iq_8)&(y8>=li_iq_8)] #Elimina esa fila
data_clean_y8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 9: panaderia
y9=data2['panaderia']
p25_9=y9.quantile(0.25)
p75_9=y9.quantile(0.75)
iqr9=p75_9-p25_9

ls_iq_9=p75_9+1.5*iqr9
li_iq_9=p25_9-1.5*iqr9
print("Límite superior 9:",ls_iq_9)
print("Límite inferior 9:",li_iq_9)
# Out:
# Límite superior 9: 5413785.027999999
# Límite inferior 9: -1094461.7159999995

# %%
#Outliers en boxplot=4
#Encontrar outliers
outliers_y9=data2[(y9>ls_iq_9)|(y9<li_iq_9)]
outliers_y9
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37      6.299968e+07
# 62                168982502.3  51262080.99      47364363.88      2.726200e+07
# ...

# %%
#df con y9 sin outliers
data_clean_y9=data2[(y9<=ls_iq_9)&(y9>=li_iq_9)] #Elimina las 4 filas
data_clean_y9
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 56    01/09/2021                   123002.3                    22962.0
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Columna 10: alimentos_preparados_rotiseria
y10=data2['alimentos_preparados_rotiseria']
p25_10=y10.quantile(0.25)
p75_10=y10.quantile(0.75)
iqr10=p75_10-p25_10

ls_iq_10=p75_10+1.5*iqr10
li_iq_10=p25_10-1.5*iqr10
print("Límite superior 9:",ls_iq_10)
print("Límite inferior 9:",li_iq_10)
# Out:
# Límite superior 9: 1587857.7785
# Límite inferior 9: -295824.8606999999

# %%
#Outliers en boxplot=4
#Encontrar outliers
outliers_y10=data2[(y10>ls_iq_10)|(y10<li_iq_10)]
outliers_y10
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2     5.116431e+06
# 62                 168982502.3   164321107.3     4.661350e+05
# 63                 177148082.8   173003799.1     4.144284e+06
# 64                 179639238.6   175358487.5     4.280751e+06
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37      6.299968e+07
# 62                168982502.3  51262080.99      47364363.88      2.726200e+07
# ...

# %%
#df con y10 sin outliers
data_clean_y10=data2[(y10<=ls_iq_10)&(y10>=li_iq_10)] #Elimina las 4 filas
data_clean_y10
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 56    01/09/2021                   123002.3                    22962.0
# 57    01/10/2021                   140487.5                    25386.7
# 58    01/11/2021                   141702.0                    25026.6
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %% [markdown]
# Guardar df limpios en csv

# %%
data_clean_y1.to_csv("clean_ventas_precios_corrientes.csv")
data_clean_y2.to_csv("clean_ventas_precios_constantes.csv")
data_clean_y3.to_csv("clean_ventas_totales_canal_venta.csv")
data_clean_y4.to_csv("clean_salon_ventas.csv")
data_clean_y5.to_csv("clean_tarjetas_debito.csv")
data_clean_y6.to_csv("clean_tarjetas_credito.csv")
data_clean_y7.to_csv("clean_subtotal_ventas_alimentos_bebidas.csv")
data_clean_y8.to_csv("clean_bebidas.csv")
data_clean_y9.to_csv("clean_panaderia.csv")
data_clean_y10.to_csv("clean_alimentos_preparados_rotiseria.csv")
